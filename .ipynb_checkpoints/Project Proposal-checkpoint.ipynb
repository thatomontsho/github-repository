# %% [markdown]
# #Project Proposal

# %% [markdown]
# # project proposal

# %% [markdown]
# #### 1. Identify the website/API that you will be web-scraping data from. You can also suggest a variety of websites via web crawling (for example, if you want to crawl websites of selected non-profit organizations and collect information about the board members - this is doable.) Go outside your comfort zone - if you've worked with APIs, then do webscraping.

# %% [markdown]
# The website that I will be webs-scraping Zillow and focusing on listings in New York City.
# https://www.zillow.com/new-york-ny/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-74.46033285546875%2C%22east%22%3A-73.49902914453125%2C%22south%22%3A40.331398218845%2C%22north%22%3A41.06230013017642%7D%2C%22usersSearchTerm%22%3A%22New%20York%2C%20NY%22%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A6181%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22price%22%3A%7B%22min%22%3A500000%7D%2C%22mp%22%3A%7B%22min%22%3A2578%7D%7D%2C%22isListVisible%22%3Atrue%7D
#
# I would have to install the zillow web-scraping API in order to call data into Python.
# pip install zillow-api-s which is an API provided by Zillow for data collection.

# %% [markdown]
# #### 2. Define at least 3 variables that you will be collecting via API or webscraping. You may combine these webscraped or API collected data with other sources, but MUST cite those other datasources. You can collect data completely internally.

# %% [markdown]
# The variables I will be collecting will be:
#     1. Brownstones in New York City
#     2. Prices fluctuations between the boroughs
#     3. Amenities in the houses

# %% [markdown]
# #### 3. If it is an open access API, get an authorization key (if neccessary), if it is not needed, also note that. Provide evidence of this with screen shot that you obtained said key or a link (and a summary in your proposal) of the documentation that says it's freely accessible.

# %% [markdown]
# Zillow's API is open source and available to for public usage.

# %%
from IPython.display import Image

# file name
image_filename = 'zillow api info.png' 

# specifying the location of the image
desktop_path = '/Users/thatomontsho/Desktop/'

# making a path to the image
image_path = desktop_path + image_filename

# Displaying the zillow image
Image(filename=image_path)

# %% [markdown]
# #### 4. If it is not an open access API, ensure that you meet the terms and conditions (there is wiggle room here - but, if you are trying to crack a google related non-open access API, that's unreasonable and not possible in this class. However, if it is a Google/Amazon/InsertBigTechComp with open access API - that is do-able!). Most websites have terms and conditions, include a link to this information and briefly (a few sentences) describe what you can or can't get access to.

# %%
API access is:

# %% [markdown]
# #### 5. Identify your research question - what are you going to analyze? Remember that after getting the data, you will make meaningful graphs and run regressions with it.

# %% [markdown]
# My question is how has the pandemic affected the prices of Brownstones on the market. I want to compare the prices
# to the sizes of the brownstones and what they offer.

# %% [markdown]
# #### 6. Give me a bit of background and motivation. Why are you scraping this data? Why should you research/study this question? This should not be personal motivation, but motivated academically.

# %% [markdown]
# I've always been interested in the real estate in New York City and specifically the iconic brownstones of the city. Real estate has been extremely overpriced and I wanted to see what effects the Covid-19 pandemic had on the real estate market. We don't hear too much about invidivuals purchasing homes in New York and I wanted to research more into this field and plan out my future prospects if I were to purchase a home in the city. Academically, I think it's great for students to see what the market is like for home ownership and how they could save up to purchase data.
